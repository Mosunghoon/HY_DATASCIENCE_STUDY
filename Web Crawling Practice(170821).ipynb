# %%
import requests ## 리퀘스트는 서버에 정보를 요청하는 모듈이다.
from bs4 import BeautifulSoup

# %%
url = 'http://www.naver.com'
html = requests.get(url).text
soup = BeautifulSoup(html, 'html.parser')

# %%
tag_list = soup.select(".PM_CL_realtimeKeyword_rolling .ah_item .ah_k")

for idx, tag in enumerate(tag_list,1):
   print(idx, tag.text)                         ## 개발자도구로 확인.

### 링크에 &가 하나씩 들어갈 때마다 조건식이 생긴다고 보면 된다.
# Out:
# 1 화유기
# 2 이지현
# 3 김민채
# 4 정운택
# 5 김명수
# 6 이사강
# 7 이승기
# 8 정담이
# 9 깨끗한나라
# 10 생리대
# 11 릴리안 생리대
# 12 릴리안
# 13 티켓링크
# 14 아이유
# 15 김진표
# 16 공무원연금관리공단
# 17 이순진
# 18 릴리안 생리대 부작용
# 19 송소희
# 20 박근혜

# %%
import requests
from bs4 import BeautifulSoup
from collections import OrderedDict
from itertools import count

def naver_blog_search(q):
   post_dict = OrderedDict()
   
   for page in count(1):
       url = 'https://search.naver.com/search.naver'
       params = {
           'query': q,
           'where': 'post',
           'start': (page-1)*10 + 1, ## 순서가 1, 11, 21 ,31 이렇게 나아간다
       }
       response = requests.get(url, params=params)
       html = response.text
       soup = BeautifulSoup(html, 'html.parser')
               
       for tag in soup.select('.sh_blog_title'):
           if tag['href'] in post_dict:
               return post_dict
           
           print(tag.text, tag['href'])
           post_dict[tag['href']] = tag.text
   return post_dict

# %%
result = naver_blog_search("한양대 정보사회학과")
# Out:
# [한양대 ERICA/정보사회학과] 한양대 정보사회학과에 대한... http://blog.naver.com/infosocio?Redirect=Log&logNo=220211149248
# [Social App] 한양대 정보사회학과의 6주간의 프로젝트! http://blog.naver.com/kooym5?Redirect=Log&logNo=221004634220
# 한양대 정보사회학과 취업 특강 | 면접커뮤니케이션... http://blog.naver.com/l_goun?Redirect=Log&logNo=221011864022
# [한양대ERICA 정보사회학과/학술제] 한양대 정보사회학과... http://blog.naver.com/sat1106?Redirect=Log&logNo=220187175430
# 한양대 정보사회학과 학술제 프로젝트팀 이음입니다! http://blog.naver.com/e_um2014?Redirect=Log&logNo=220127912430
# 안산수학과외] 한양대 정보사회학과 여자선생님입니다. http://blog.naver.com/studydalin1?Redirect=Log&logNo=188192566
# 정보사회학」에 관심있는 분들을 위해... http://blog.naver.com/udamin?Redirect=Log&logNo=30178784511
# 정보사회학페이지는 왜 사람들에게 인기를 끄는가? http://blog.naver.com/blk_lg_ryan?Redirect=Log&logNo=130111540793
# 한양대 에리카 2017년 신입생환영회! / 광고 홍보학과 뒷풀이... http://blog.naver.com/no7913?Redirect=Log&logNo=220938271173
# 한양대 에리카 수시 전형별 전공별 모집인원 http://blog.naver.com/earbri?Redirect=Log&logNo=221077550067
# ...

# %%
len(result)
# Out:
# 630
